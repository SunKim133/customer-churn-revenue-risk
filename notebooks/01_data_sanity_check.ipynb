# %% [markdown]
# # 01. Data Sanity Check

# %% [markdown]
# ## Data & Library Imports

# %%
import pandas as pd

# %%
df = pd.read_csv("../data/telco_churn.csv")
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# ## Shape & Columns

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.columns.tolist()
# Out:
# ['customerID',
#  'gender',
#  'SeniorCitizen',
#  'Partner',
#  'Dependents',
#  'tenure',
#  'PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod',
#  'MonthlyCharges',
#  'TotalCharges',
#  'Churn']

# %% [markdown]
# ## Target Variable Check

# %%
df['Churn'].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
df["Churn"].value_counts(normalize=True)
# Out:
# Churn
# No     0.73463
# Yes    0.26537
# Name: proportion, dtype: float64

# %% [markdown]
# The target variable `Churn` is binary, with approximately 73% of customers classified as non-churned.

# %% [markdown]
# ## Revenue Fields Check

# %%
df[["MonthlyCharges", "TotalCharges"]].describe()
# Out:
#        MonthlyCharges
# count     7043.000000
# mean        64.761692
# std         30.090047
# min         18.250000
# 25%         35.500000
# 50%         70.350000
# 75%         89.850000
# max        118.750000

# %% [markdown]
# Let's check `TotalCharges` column:

# %%
df['TotalCharges'].dtypes
# Out:
# dtype('O')

# %% [markdown]
# The `TotalCharges` field is stored as an object rather than a numeric type. As a result, it will need preprocessing before quantitative analysis.

# %% [markdown]
# ## Missing Values Check

# %%
df.isna().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [markdown]
# ## Sanity Check Summary

# %% [markdown]
# - Dataset contains 7043 rows and 21 columns.
# - Target variable `Churn` is binary with a churn rate of approximately 26.5%.
# - `MonthlyCharges` is numeric and suitable as a short-term revenue proxy.
# - `TotalCharges` contains missing or non-numeric values and may require cleaning.
# - No critical missing values were found in the churn target.
#
# Based on this review, the dataset is suitable for exploratory and modeling analysis with noted limitations.
